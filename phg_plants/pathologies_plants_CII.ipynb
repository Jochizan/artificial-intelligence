# %% [markdown]
# # Proyecto IA para el reconocimiento de enfermedades en plantas
#
# # Proyecto IA para el reconocimiento de enfermadades en plantas de la región
#
# # Proyecto IA para el reconocimiento de enfermadades en plantas con un Dataset de Kaggle con medio millon de muestras de varias zonas del mundo
#
# ### (Nota) => Posibles titulos?

# %%
title_one = 'Proyecto IA para el reconocimiento de enfermedades en plantas'.split(' ')
title_two = 'Proyecto IA para el reconocimiento de enfermadades en plantas de la región'.split(' ')
title_three = 'Proyecto IA para el reconocimiento de enfermadades en plantas con un Dataset de Kaggle con medio millon de muestras de varias zonas del mundo'.split(' ')

print('Cantidad de palabras:','\n\ttitulo uno:', len(title_one), '\n\ttitulo dos:', len(title_two), '\n\ttitulo tres:', len(title_three))
# Out:
# Cantidad de palabras:
# 	titulo uno: 9
# 	titulo dos: 12
# 	titulo tres: 24

# %% [markdown]
# ## Descripción del problema:
#
# - Elaborar un programa en Python que permita realizar el reconocimiento de enfermedades en plantas de la región,  utilizando  una  cámara  web.  Debe  utilizar  Deep  Learning  (obligatorio)  y  alguna  otra  técnica  de Inteligencia Artificial que considere conveniente (libre). Además el programa debe mencionar si la planta tiene alguna enfermedad.

# %% [markdown]
# ### La presentación del avance para el consolidado 2 considera lo siguiente:
#
# - a) Título. El puntaje y criterios de evaluación se encuentran en el anexo 1. (04 Puntos)
# - b) Introducción. El puntaje y criterios de evaluación se encuentran en el anexo 1. (15 puntos)
# - c) Cuerpo:
#     - Se debe elegir el método, estrategia o buena práctica. No se pide la implementación en este punto,
# solamente la elección con su respectiva justificación. (04 puntos)
#     - Considera técnicas, instrumentos o herramienta de recopilación de información. Mencionar las
# fuentes de donde se obtendrá la información (03 puntos).

# %% [markdown]
# #### Los ítems para la calificación consideran el avance del artículo y exposición basado en la JORNADA DE INVESTIGACIÓN  FORMATIVA  Y  TECNOLÓGICA  DE  LA  FACULTAD  DE  INGENIERÍA  DE SISTEMAS. La calificación de 0 a 26 será convertida a la calificación vigesimal a través de una regla de tres simple.

# %% [markdown]
# #### El avance del artículo se debe subir a la plataforma Teams.

# %% [markdown]
# #### Solo debe subir un integrante del grupo.

# %% [markdown]
# ![imagen.png](attachment:cebd2708-085a-485a-b034-a850305ecb2b.png)

# %% [markdown]
# ## Introducción:
#
# - Según la Organización de las Naciones Unidas para la Alimentación y la Agricultura (FAO) a nivel mundial una de las principales causas de pérdidas en precosecha de nuestro país y similares es debido a enfermedades en plantas que llegan a ser hasta de poco más del 24% en nuestro caso (véase, por ejemplo "El estado mundial de la agricultura y la alimentación" [Citación como pide el ingeniero], "Plan nacional de cultivos 2019 2020", [2]), por lo tanto, se ve la necesidad de detectar de manera inmediata estas enfermedades que afectan a nuestra agricultura para poder evitar las perdidas con el tratamiento adecuado, es por eso que se plantea nuestro proyecto para la detección de enfermedades a través de redes neuronales de aprendizaje profundo para detectar las enfermedades más usuales que afectan a las plantaciones hoy en día, y es que el método tradicional de detección de enfermedades ha sido el uso de exámenes manuales por parte de agricultores o expertos lo que puede llevar mucho tiempo y ser costoso y que resulta inviable para miles de agricultores pequeñas y medianas en todo el mundo.
#
# - Como en proyectos basados en detección de enfermedades en plantas el mayor desafío son las dificultades para describir los síntomas para su identificación por computadora es por eso que mediante el uso de aprendizaje profundo donde los modelos no necesitan que se describan las características, sino que aprenden las características mediante la optimización. Ya que se han visto buenos resultados por el uso de los modelos de aprendizaje profundo para lograr con éxito varios niveles de precisión en imágenes de laboratorio/campo con respecto al tema (véase "Plant Disease Identification Based on Deep Learning Algorithm in Smart Farming"[3], "Using Deep Learning for Image-Based Plant Disease Detection" [4]), pero podemos dar a entender que ha pesar de tener buenas precisiones estos modelos llegan a fallar bastante con datos diferentes. Es entonces que se deben identificar los factores que afectan el rendimiento de los modelos de aprendizaje profundo aplicados a la detección de enfermedades por las hojas de las plantas, y concluir que a pesar de la tasa de éxito significativamente alta de los sistemas desarrollados hay varias razones que hacen todavía poco manejable, en conjunto con un aplicativo, una herramienta genérica que podría utilizarse en condiciones reales.
#
# - Es relevante aclarar el conjunto de datos a utilizar será de Kaggle ("comunidad en línea de científicos de datos y profesionales del aprendizaje automático" [5]), que nos da de varios datasets de otros temas para el desarrollo de alguna red neuronal, pero en el caso de patologías a plantas nos dota de imágenes con baja variabilidad y antecedentes similares, y que son mayores a las quinientos mil muestras. Los tipos de planta que se presentan en el dataset son de soja, tomates, manzanas, naranjas, pimiento, papas, uvas, maíz, melocotón, cereza, fresa, arándano, frambuesa y calabaza. Este trabajo de investigación sigue un enfoque similar a los proyectos realizados con deep learning en este campo es así que para utilizar la máxima información sobre los síntomas de la enfermedad mediante el uso de redese neuronales convolucionales verificaremos los resultados de dos modelos, para comparar la confianza y precisión de la autoclasificación para los casos de saludable, mancha bacteriana, podredumbre negra, tizón temprano, tizón tardío, entre otros (Opcional ()), y con esto demostrar que podemos a través de nuestro dataset obtener muy buenos resultados incluso en condiciones del mundo real.

# %% [markdown]
# - Palabras clave:
#     * Procesamiento de imágenes
#     * Redes neuronales profundas
#     * Base de datos de imágenes
#     * Clasificación de enfermedades

# %% [markdown]
# Opcional mostrar todas las enfermedades (mildiú polvoriento, costra de manzana, haunglongbing (verde_cítrico), virus del rizado de la hoja amarilla del tomate, esca (sarampión_negro), tizón de la hoja del norte, óxido común, molde de hoja, punto de destino, virus del mosaico del tomate, quemaduras de hojas, óxido de manzana de cedro, mancha foliar por septoria, ácaros araña dos ácaros manchados, tizón foliar (mancha foliar por isariopsis), mancha foliar por cercospora mancha foliar gris)

# %% [markdown]
# ## Cuerpo:
#
# ### Método, estrategia o buena práctica. -> miren los 4 videos ...
#
# ### Tecnicas -> Estefany?
#
# ### Instrumentos y herramientos.
#
# #### Lenguages
#
# - Python
# - JavaScript
#
# #### Notebooks
#
# - Jupyter Notebook
# - Jupyter Lab
#
# #### IDE
#
# - PyCharm Profesional
# - Web Storm
# - VS Code
#
# #### Distribuciones
#
# - Anaconda
#
# #### Frameworks y/o Librerias
#
# - Tensorflow
# - Tfjs
# - React ?
# - React-Native ?
# - Keras
# - Sklearn
